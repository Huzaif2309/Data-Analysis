# %% [markdown]
# # Introduction
#
# Tuberculosis (TB) is one of the most common infectious diseases worldwide. For several decades, the research community has been working for an effective preventive strategy for TB. It is clear that although the current preventive efforts against the spread of TB have lowered its incidence, the problem is far from over. Therefore the focus of research has now shifted to the previously untargeted risk factors involved in the spread of TB. One such factor is diabetes mellitus (DM). It is well known that DM impairs the immunity of patients and therefore is an independent risk factor for infections such as TB.
#
# Reports on the association between DM and TB date back to 1000 A.D.; when Avicenna noted that ‘phthisis’, (Greek: tuberculosis), often complicated diabetes and that the presence of diabetes resulted in an increased risk of developing TB. Another description is seen in the works of Yugimahamuni, a traditional Indian saint. He described the association of DM and TB by a combination of symptoms called ‘meganoikal’. These symptoms included obesity, glycosuria, thirst, incontinence, respiratory symptoms and unconsciousness.
#
# Each disease is thought to exacerbate and worsen the outcome for the other. TB is a specific morbidity often associated with DM and is therefore aptly described as a complication of DM. People with diabetes are more susceptible to infections and suffer from relatively severe illness due to their immuno-compromised status , with reactivation of older foci of TB rather than through fresh contact , and often exhibit lower lobe involvement more commonly than in non-diabetics. Various studies have shown that 5-30% of patients with TB have DM as well.[6].

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('C:/Users/admin/Desktop/tbdd.jpg')
fig, ax = plt.subplots(figsize=(15, 10))
ax.imshow(img)
ax.axis('off')
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes, mark_inset


# %matplotlib inline

# %%
df=pd.read_csv('C:/Users/admin/Downloads/TB2.csv')

# %%
df.head()
# Out:
#                                            State/Uts  \
# 0  No of TB - Diabetes-TB patients with known DM ...
# 1  Percentage  of TB - Diabetes-TB patients with ...
# 2  No of TB - Diabetes-TB patients with known DM ...
# 3  Percentage  of TB - Diabetes-TB patients with ...
# 4  No of TB - Diabetes-TB patients with known DM ...
#
#    Andaman & Nicobar Islands  Andhra Pradesh  Arunachal Pradesh    Assam  \
# 0                      518.0         65235.0             2378.0  34011.0
# 1                       95.2            98.7               79.0     81.0
# 2                        3.0         26883.0                3.0   4929.0
# 3                       75.0            99.6               50.0     83.2
# 4                      521.0         92118.0             2381.0  38940.0
#
#       Bihar  Chandigarh  Chhattisgarh  \
# 0   53768.0      3531.0       26987.0
# 1      66.1        94.9          91.6
# 2   74114.0        47.0        8243.0
# 3      87.7        73.4          88.8
# ...

# %%
df.shape
# Out:
# (18, 38)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 38 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   State/Uts                                 18 non-null     object
#  1   Andaman & Nicobar Islands                 18 non-null     float64
#  2   Andhra Pradesh                            18 non-null     float64
#  3   Arunachal Pradesh                         16 non-null     float64
#  4   Assam                                     18 non-null     float64
#  5   Bihar                                     18 non-null     float64
#  6   Chandigarh                                18 non-null     float64
#  7   Chhattisgarh                              18 non-null     float64
#  8   Dadra and Nagar Haveli and Daman and Diu  18 non-null     float64
#  9   Delhi                                     18 non-null     float64
# ...

# %%
df.describe()
# Out:
#        Andaman & Nicobar Islands  Andhra Pradesh  Arunachal Pradesh  \
# count                  18.000000       18.000000           16.00000
# mean                  108.700000    12454.677778          327.75000
# std                   153.673608    25439.666377          801.38921
# min                     1.000000       10.900000            0.00000
# 25%                    22.425000       68.600000            2.87500
# 50%                    71.250000      885.300000           47.50000
# 75%                    96.550000     8600.250000           64.00000
# max                   521.000000    92118.000000         2381.00000
#
#               Assam          Bihar   Chandigarh  Chhattisgarh  \
# count     18.000000      18.000000    18.000000     18.000000
# mean    4818.594444   15246.694444   491.816667   4431.911111
# std    11626.490911   34837.850768  1119.159232  10009.706989
# min        7.500000       5.100000     5.000000      7.800000
# ...

# %%
df.isna().sum()
# Out:
# State/Uts                                   0
# Andaman & Nicobar Islands                   0
# Andhra Pradesh                              0
# Arunachal Pradesh                           2
# Assam                                       0
# Bihar                                       0
# Chandigarh                                  0
# Chhattisgarh                                0
# Dadra and Nagar Haveli and Daman and Diu    0
# Delhi                                       0
# Goa                                         0
# Gujarat                                     0
# Haryana                                     0
# Himachal Pradesh                            0
# Jammu & Kashmir                             0
# Jharkhand                                   0
# Karnataka                                   0
# Kerala                                      0
# Ladakh                                      0
# Lakshadweep                                 6
# ...

# %%
df[['Arunachal Pradesh', 'Lakshadweep','Puducherry']] = df[['Arunachal Pradesh', 'Lakshadweep','Puducherry']].fillna(df[['Arunachal Pradesh', 'Lakshadweep','Puducherry']].mean())

# %%
df.isna().sum()
# Out:
# State/Uts                                   0
# Andaman & Nicobar Islands                   0
# Andhra Pradesh                              0
# Arunachal Pradesh                           0
# Assam                                       0
# Bihar                                       0
# Chandigarh                                  0
# Chhattisgarh                                0
# Dadra and Nagar Haveli and Daman and Diu    0
# Delhi                                       0
# Goa                                         0
# Gujarat                                     0
# Haryana                                     0
# Himachal Pradesh                            0
# Jammu & Kashmir                             0
# Jharkhand                                   0
# Karnataka                                   0
# Kerala                                      0
# Ladakh                                      0
# Lakshadweep                                 0
# ...

# %% [markdown]
# ## Risk Factors for TB Infection, Disease, and Outcome

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('C:/Users/admin/Desktop/123.png')
fig, ax = plt.subplots(figsize=(15, 10))
ax.imshow(img)
ax.axis('off')
plt.show()

# %%
selected_columns = ['Delhi','Tamil Nadu', 'Karnataka', 'Maharashtra']


df = pd.read_csv('C:/Users/admin/Downloads/TB2.csv', usecols=selected_columns)

df = df.applymap(str)

selected_rows = [6,12,18]
for row_index in selected_rows:
    if 0 < row_index <= len(df):
        plt.plot(df.columns, df.iloc[row_index - 1], label=f'Row {row_index}', marker='o')
    else:
        print(f"Row {row_index} is out of bounds for the DataFrame.")

plt.title('')
plt.xlabel('Metropolitain States')
plt.ylabel('Percentages')
plt.grid(True)
plt.legend()

plt.show()

# %% [markdown]
# The line plot depicting Diabetes-TB patients with known DM status, notified diagnoses among those tested, and patients initiated on
# Anti-diabetic treatment in different Metropolitan States reveals notable trends.
# Notably, Tamil Nadu exhibits a higher percentage of diagnosed Diabetes-TB cases and demonstrates proactive measures in Anti-diabetic Treatment.
# Conversely, Delhi shows a lower percentage of Diabetes-TB diagnoses and consequently lower Anti-diabetic Treatment rates.
# Despite Tamil Nadu's high Anti-diabetic Treatment percentage, the overall proportion concerning TB-Diabetes diagnoses is relatively low at 9.2%.
# This underscores the need for targeted interventions and strategic measures in Tamil Nadu to address the situation effectively.
#
#
# **Note:**
#
# *Row 6 indicates Percentage of Diabetes-TB patients with known DM status*
#
# *Row 12 indicates Percentage of Diabetes-TB patients with notified diagnoses among those tested*
#
# *Row 18 indicates Percentage of Diabetes-TB patients who have initiated on Anti-diabetic treatment*

# %%
selected_columns = ['Arunachal Pradesh', 'Jharkhand', 'Bihar','Rajasthan']

df = pd.read_csv('C:/Users/admin/Downloads/TB2.csv', usecols=selected_columns)

df = df.apply(pd.to_numeric, errors='coerce')

selected_rows = [6, 18,12]
bar_width = 0.25  
bar_colors = ['orange', 'green', 'blue']

for i, row_index in enumerate(selected_rows):
    if 0 < row_index <= len(df):
        bars = plt.bar(np.arange(len(df.columns)) + i * bar_width, df.iloc[row_index - 1],
                       width=bar_width, label=f'Row {row_index}', color=bar_colors[i])

plt.title('')
plt.xlabel('Low Literacy Rate States')
plt.ylabel('Percentages')
plt.xticks(np.arange(len(df.columns)) + bar_width, df.columns)  # Set x-axis ticks
plt.legend()
plt.show()

# %% [markdown]
# The bar plot illustrating Diabetes-TB cases with known DM status, notified diagnoses among those tested, and patients initiated on
# Anti-diabetic treatment in the Least Literate States reveals discernible patterns.
# Notably, Rajasthan demonstrates a heightened percentage of diagnosed Diabetes-TB cases, accompanied by proactive measures in Anti-diabetic Treatment.
# Conversely, Arunachal Pradesh exhibits a lower percentage of Diabetes-TB diagnoses, correlating with comparatively
# reduced rates of Anti-diabetic Treatment initiation.
# Despite Rajasthan's commendable Anti-diabetic Treatment percentage, the overall proportion of TB-Diabetes diagnoses remains relatively modest at 33.2%.
# This underscores the imperative for precision-targeted interventions and strategic measures in Rajasthan to effectively address this healthcare scenario
#
# **Note:**
#
# *Row 6 indicates Percentage of Diabetes-TB patients with known DM status*
#
# *Row 12 indicates Percentage of Diabetes-TB patients with notified diagnoses among those tested*
#
# *Row 18 indicates Percentage of Diabetes-TB patients who have initiated on Anti-diabetic treatment*

# %% [markdown]
# ## Anti-Diabetic Drug Use in Patients with Tuberculosis

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('C:/Users/admin/Desktop/124.png')
fig, ax = plt.subplots(figsize=(15,10))
ax.imshow(img)
ax.axis('off')
plt.show()

# %%
selected_columns = ['Odisha', 'Kerala', 'Bihar']

df = pd.read_csv('C:/Users/admin/Downloads/TB2.csv', usecols=selected_columns)

df = df.applymap(str)

selected_rows = [6, 12, 18]

percentages_list = []

for row_index in selected_rows:
    if 0 < row_index <= len(df):
        percentages_list.append(df.iloc[row_index - 1].astype(float))
    else:
        print(f"Row {row_index} is out of bounds for the DataFrame.")

for i, percentages in enumerate(percentages_list):
    plt.figure()
    plt.pie(percentages, labels=df.columns, autopct='%1.1f%%', startangle=90)
    plt.title(f'Pie Chart for Row {selected_rows[i]}')

plt.show()

# %% [markdown]
# The enchanting visual narrative through a pie plot unveils intriguing insights into Diabetes-TB dynamics, known DM status, notified diagnoses, and the initiation of Anti-diabetic
# treatment across selected states.
# In this captivating tableau, Odisha emerges as a beacon, boasting a notable surge in diagnosed Diabetes-TB cases,
# coupled with a laudable commitment to proactive Anti-diabetic Treatment measures.
# On the other hand, Bihar gracefully takes its place with a lower percentage of Diabetes-TB diagnoses, accompanied by a modest initiation rate of Anti-diabetic Treatment.
# Despite Odisha's admirable Anti-diabetic Treatment percentage, the overall proportion of TB-Diabetes diagnoses modestly rests at 27.1%.
# This narrative not only piques curiosity but also underscores the pressing need for nuanced, targeted interventions and strategic healthcare measures in
# Odisha to elevate the state's health landscape.
#
# **Note:**
#
# *Row 6 indicates Percentage of Diabetes-TB patients with known DM status*
#
# *Row 12 indicates Percentage of Diabetes-TB patients with notified diagnoses among those tested*
#
# *Row 18 indicates Percentage of Diabetes-TB patients who have initiated on Anti-diabetic treatment*

# %%
selected_columns = ['Chhattisgarh', 'Uttar Pradesh', 'Lakshadweep']

df = pd.read_csv('C:/Users/admin/Downloads/TB2.csv', usecols=selected_columns)

df = df.apply(pd.to_numeric, errors='coerce')

selected_rows = [6, 18, 12]
line_colors = ['orange', 'green', 'blue']

for i, row_index in enumerate(selected_rows):
    if 0 < row_index <= len(df):
        plt.plot(df.columns, df.iloc[row_index - 1], label=f'Row {row_index}', color=line_colors[i], marker='o')

plt.title('Comparison based on Population')
plt.xlabel('States/UTs')
plt.ylabel('Percentages')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img1_path = r'C:\\Users\\admin\\Desktop\\population.jpg'
img1 = mpimg.imread(img1_path)
img2_path = r'C:\\Users\\admin\\Desktop\\tbdm.png'
img2 = mpimg.imread(img2_path)
fig, axarr = plt.subplots(1, 2, figsize=(12, 6))
axarr[0].imshow(img1)
axarr[0].set_title('Image 1')
axarr[0].axis('off')
axarr[1].imshow(img2)
axarr[1].set_title('Image 2')
axarr[1].axis('off')
plt.tight_layout()

plt.show()

# %% [markdown]
# In this line chart, we compare the proportion of patients with known tuberculosis who also suffer from Diabetes Mellitus,
# the percentage of TB patients who are diagnosed with DM out of the tested ones and the number of diabetic patients who are on both DM and TB medication,represented by orange, green and blue colors respectively, across 3 states.
#
# We can see that the incidence of DM in patients who suffer from TB is fairly constant across the states compared.
# This matches with the overall percentage both in India and worldwide, which implies that TB may be a causative factor for DM.
# The diagnosis of DM in patients who already suffer from TB is almost uniform in Chhattisgarh and Uttar Pradesh, but higher in Lakshadweep.
# We must also note that the percentage of DM affected individuals who are undergoing treatment for both TB and DM is the highest in Lakshadweep.
# This might be due to its higher DM diagnosis rate, causing a correspondingly larger population size of patients taking medication for the same.
#
# **Note:**
#
# *Row 6 indicates Percentage of Diabetes-TB patients with known DM status*
#
# *Row 12 indicates Percentage of Diabetes-TB patients with notified diagnoses among those tested*
#
# *Row 18 indicates Percentage of Diabetes-TB patients who have initiated on Anti-diabetic treatment*

# %%
selected_columns = ['Goa', 'Mizoram', 'Bihar']

df = pd.read_csv('C:/Users/admin/Downloads/TB2.csv', usecols=selected_columns)

df = df.applymap(str)

selected_rows = [6, 12, 18]

percentages_list = []
for row_index in selected_rows:
    if 0 < row_index <= len(df):
        percentages_list.append(df.iloc[row_index - 1].astype(float))
    else:
        print(f"Row {row_index} is out of bounds for the DataFrame.")

for i, percentages in enumerate(percentages_list):
    plt.figure()
    plt.pie(percentages, labels=df.columns, autopct='%1.1f%%', startangle=90)
    plt.title(f'Pie Chart for Row {selected_rows[i]}')

plt.xlabel('Comparision based on GSDP Per Capita')
plt.show()

# %% [markdown]
# In this pie chart, we compared income with the incidence of diseases.
# The attributes we compare are  the proportion of patients with known tuberculosis who also suffer from Diabetes Mellitus,
# the percentage of TB patients who are diagnosed with DM out of the tested ones and the number of diabetic patients who are on both DM and TB medication,
# represented by orange, green and blue colors respectively.
#
# GSDP(Gross State Domestic Produce) is a well known indicator of economic wealth and stability.
# Out of the three states shown in this graph, the greatest GSDP is that of Bihar’s, followed by Goa and Mizoram.
# However, Bihar’s population is around 70 times greater than Mizoram and Goa.
# Thus, we use the GDSP per capita as a more accurate indicator represented by the X axis in this graph as the independent variable.
# The organization of states with respect to GDSP per capita is exactly opposite to that of just GDSP; the descending order of GDSP per capita is Goa,
# Mizoram and Bihar. While comparing in this way, we see that the wealthier states have higher rates of both incidence and occurrence of DM and TB.
# This is in agreement with published research that higher income groups are more predisposed to DM and other lifestyle related illnesses like cardiovascular disease.
#
# THe prevalence of diabetes across India is varied. Preliminary results from a large community study conducted by the Indian Council of Medical research (ICMR) revealed
# that a lower proportion of the population is affected in states of Northern India (Chandigarh 0.12 million, Jharkhand 0.96 million) as compared to Maharashtra (9.2 million) and
# Tamil Nadu (4.8 million). A suggested explanation for this difference is that the north Indians are migrant Asian populations and south Indians are the host populations,
# however this possible cause-and-effect has not been corroborated through further research.
#
# Similar ethnographic disparities have been observed in indigenous and non-indigenous populations in countries colonized by the Great Britain:
# indigenous people from New Zealand and Australia have been shown to suffer from diabetes and cardio-metabolic disorders more than the non-indigenous people.
# Further studies are required in India to highlight cultural and ethnic trends and provide a more complete understanding of the
# differences in diabetes etiology between Indian and other ethnic groups within India.
#
# The incidence of tuberculosis is reducing in India,however we still have the highest burden of this disease.
# Reported TB death totals decreased across 28 states, with the largest percent decrease being seen in Lakshadweep (100% decrease with zero deaths in 2020),
# Andaman and Nicobar Islands (36.0% decrease), Andhra Pradesh (30.5% decrease), and Manipur (25.7% decrease).
# Notably, there was a decrease of 3,496 total TB deaths in Uttar Pradesh over this time period (19.0% decrease).
# Total TB deaths increased in seven states, with the largest percent increases occurring in Goa (23.6% increase), Arunachal Pradesh (21.9% increase), and Jharkhand (19.3% increase).
#
# We see that India houses one of the world’s largest diabetic population along with the most number of TUberculosis patients.
# This places India in a unique position to tackle the dual diseases of TB and DM- placing a harsher burden on the healthcare system.
#
# However, we may note that while the age group most affected by DM is >55, TB mostly occurs in infancy.
# Also, while the rates of DM incidence in India are on an upward trend, TB cases are reducing- but India still remains the capital worldwide for both these diseases.
#
# **Note:**
#
# *Row 6 indicates Percentage of Diabetes-TB patients with known DM status*
#
# *Row 12 indicates Percentage of Diabetes-TB patients with notified diagnoses among those tested*
#
# *Row 18 indicates Percentage of Diabetes-TB patients who have initiated on Anti-diabetic treatment*

# %% [markdown]
# ## Here is a correlation for the below graphs

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('C:/Users/admin/Desktop/corr.jpg')
fig, ax = plt.subplots(figsize=(15, 10))
ax.imshow(img)
ax.axis('off')
plt.show()

# %%
selected_columns = ['Delhi', 'Uttar Pradesh', 'Odisha']
df = pd.read_csv('C:/Users/admin/Downloads/TB2.csv', usecols=selected_columns)
df = df.apply(pd.to_numeric, errors='coerce')
selected_rows = [6, 18, 12]
bar_width = 0.25
bar_colors = ['orange', 'green', 'blue']

for i, row_index in enumerate(selected_rows):
    if 0 < row_index <= len(df):
        bars = plt.bar(np.arange(len(df.columns)) + i * bar_width, df.iloc[row_index - 1],
                       width=bar_width, label=f'Row {row_index}', color=bar_colors[i])

plt.title('')
plt.xlabel('Comparison based on life expectancy')
plt.ylabel('Percentages')
plt.xticks(np.arange(len(df.columns)) + bar_width, df.columns)  # Set x-axis ticks
plt.legend()
plt.show()

# %% [markdown]
# **Life expectancy and DM treatment**: One interesting correlation is between the percent of TB-DM diagnosed patients who were initiated on anti-DM treatment,
# and the life expectancy of a state (r=0.37). We believe that the former does not cause the latter,
# but that both are characteristics of a state with a strong healthcare system. We claim this because TB cases by themselves have a negligible impact on life expectancy,
# as seen by the very low correlation between life expectancy and prevalence of TB.
#
# **DM Testing and DM Diagnosis**: (r=0.3) This is very interesting. The two quantities at hand are:
# proportion of TB patients whose DM status is known; and
# proportion of TB-DM patients diagnosed among those tested.
# One might ab initio expect these to be independent, for why should DM prevalence among TB patients depend on how many were tested for it?
# We propose the following explanation: it is not that (1) causes (2), but that (2) causes (1).
# States which have a higher prevalence of DM (at least among TB patients) are encouraged to test for it more,
# since these tests have a higher likelihood of yielding a positive result (so that such patients can be initiated on anti-DM treatment).
# This also explains the correlation between (1) and
#  the proportion of TB-DM patients who were initiated on anti-DM treatment
# (combined with the fact that good health care will show both).
# (2) and (3) also show a similar correlation.
#
# **Note:**
#
# *Row 6 indicates Percentage of Diabetes-TB patients with known DM status*
#
# *Row 12 indicates Percentage of Diabetes-TB patients with notified diagnoses among those tested*
#
# *Row 18 indicates Percentage of Diabetes-TB patients who have initiated on Anti-diabetic treatment*

# %%
selected_columns = ['Kerala', 'Bihar', 'Arunachal Pradesh']
df = pd.read_csv('C:/Users/admin/Downloads/TB2.csv', usecols=selected_columns)
df = df.apply(pd.to_numeric, errors='coerce')
selected_rows = [6, 18, 12]
fig, ax = plt.subplots()
for i, row_index in enumerate(selected_rows):
    if 0 < row_index <= len(df):
        selected_data = df.iloc[row_index - 1]
        ax.scatter(np.arange(len(df.columns)) + i * bar_width, selected_data,
                   label=f'Row {row_index}', color=bar_colors[i])
        ax.plot(np.arange(len(df.columns)) + i * bar_width, selected_data, linestyle='-', color=bar_colors[i])
ax.set_title('Scatter Line Plot')
ax.set_xlabel('States')
ax.set_ylabel('Percentage')
ax.set_xticks(np.arange(len(df.columns)) + bar_width / 2)
ax.set_xticklabels(df.columns)
plt.xlabel('Comparision based on Poverty rates')
ax.legend()
plt.show()

# %% [markdown]
# **Poverty**: Poverty is highly negatively correlated (r=-0.55) to the proportion of TB patients whose DM status is known.
# This signals that poor states are short on either resources or policy, and therefore test for DM much less than their richer counterparts.
# This highlights an area where work must be done.
# Poverty is similarly negatively correlated to the proportion of TB patients diagnosed with DM, who were initiated on treatment for it.
# This again highlights the same issues that the poor states face.
#
# **Note:**
#
# *Row 6 indicates Percentage of Diabetes-TB patients with known DM status*
#
# *Row 12 indicates Percentage of Diabetes-TB patients with notified diagnoses among those tested*
#
# *Row 18 indicates Percentage of Diabetes-TB patients who have initiated on Anti-diabetic treatment*

# %% [markdown]
# # Conclusion

# %% [markdown]
# There is a bidirectional relationship between TB and diabetes, and they both impact the presentation of each other. Diabetes is being increasingly recognized as a risk factor for TB and may affect its presentation, whilst TB may worsen glycemic control or lead to IGT among TB patients.
# This relationship demands adjustment in treatment and the need to employ insulin in the treatment of hyperglycemia during active TB infection when required.
#
# The TB/DM integrated management is still evolving in India and there are challenges and opportunities. The vast network of public health facilities offers opportunities to improve the service delivery. The challenge lies in strengthening the individual programs and to envision and implement a horizontal-vertical integration. Understanding the stakeholder perspectives on the challenges and opportunities in effective integration is an important step in devising solutions. Our study points to the importance of decentralization of care and strengthening the district level coordination to enable bi-directional screening and management of TB/DM comorbidities. The disease control programs need to generate more data for better decision-making and close the skill gaps to improve integrated TB/DM management.
#
# **IGT: Impaired glucose tolerance**
